-- %% [markdown]
-- # [bdsiscontrol]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [bdsiscontrol]    Script Date: 19/01/2025 15:38:59 ******/
CREATE DATABASE [bdsiscontrol]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'bdsiscontrol', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\bdsiscontrol.mdf' , SIZE = 5120KB , MAXSIZE = UNLIMITED, FILEGROWTH = 1024KB )
 LOG ON 
( NAME = N'bdsiscontrol_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\bdsiscontrol_log.ldf' , SIZE = 4224KB , MAXSIZE = 2048GB , FILEGROWTH = 10%)
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [bdsiscontrol] SET COMPATIBILITY_LEVEL = 100
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [bdsiscontrol].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [bdsiscontrol] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [bdsiscontrol] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [bdsiscontrol] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [bdsiscontrol] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [bdsiscontrol] SET ARITHABORT OFF 
GO
ALTER DATABASE [bdsiscontrol] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [bdsiscontrol] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [bdsiscontrol] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [bdsiscontrol] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [bdsiscontrol] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [bdsiscontrol] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [bdsiscontrol] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [bdsiscontrol] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [bdsiscontrol] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [bdsiscontrol] SET  DISABLE_BROKER 
GO
ALTER DATABASE [bdsiscontrol] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [bdsiscontrol] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [bdsiscontrol] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [bdsiscontrol] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [bdsiscontrol] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [bdsiscontrol] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [bdsiscontrol] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [bdsiscontrol] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [bdsiscontrol] SET  MULTI_USER 
GO
ALTER DATABASE [bdsiscontrol] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [bdsiscontrol] SET DB_CHAINING OFF 
GO
ALTER DATABASE [bdsiscontrol] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [bdsiscontrol] SET TARGET_RECOVERY_TIME = 0 SECONDS 
GO
ALTER DATABASE [bdsiscontrol] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [bdsiscontrol] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [bdsiscontrol] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Categoria]

-- %%
USE [bdsiscontrol]
GO

-- %%
/****** Object:  Table [dbo].[Categoria]    Script Date: 19/01/2025 15:38:59 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Categoria](
	[CategoriaID] [int] NOT NULL,
	[NomeCategoria] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[CategoriaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cidade]

-- %%
/****** Object:  Table [dbo].[Cidade]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cidade](
	[CidadeID] [int] NOT NULL,
	[NomeCidade] [nvarchar](100) NULL,
	[EstadoID] [int] NULL,
	[ibge] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[CidadeID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Cliente]

-- %%
/****** Object:  Table [dbo].[Cliente]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cliente](
	[ClienteID] [int] NOT NULL,
	[NomeCliente] [nvarchar](100) NOT NULL,
	[Cpf] [varchar](14) NULL,
	[Email] [nvarchar](100) NULL,
	[Endereco] [varchar](150) NULL,
	[Telefone] [varchar](20) NULL,
	[CidadeID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ClienteID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContaReceber]

-- %%
/****** Object:  Table [dbo].[ContaReceber]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContaReceber](
	[VendaID] [uniqueidentifier] NOT NULL,
	[ParcelaID] [uniqueidentifier] NOT NULL,
	[DataRecebimento] [datetime] NULL,
	[ValorRecebido] [decimal](18, 2) NOT NULL,
	[SaldoRestante] [decimal](18, 2) NOT NULL,
	[Pago] [bit] NOT NULL,
	[ContaReceberID] [uniqueidentifier] NOT NULL,
 CONSTRAINT [PK_ContaReceber] PRIMARY KEY CLUSTERED 
(
	[ContaReceberID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ContasAPagar]

-- %%
/****** Object:  Table [dbo].[ContasAPagar]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ContasAPagar](
	[ContaPagarID] [int] NOT NULL,
	[FornecedorID] [int] NULL,
	[DataVencimento] [date] NULL,
	[ValorTotal] [decimal](10, 2) NULL,
	[Pago] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[ContaPagarID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Estado]

-- %%
/****** Object:  Table [dbo].[Estado]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Estado](
	[EstadoID] [int] NOT NULL,
	[NomeEstado] [nvarchar](100) NULL,
	[Uf] [nvarchar](2) NULL,
	[Ibge] [int] NULL,
	[Pais] [int] NULL,
	[ddd] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[EstadoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fabricantes]

-- %%
/****** Object:  Table [dbo].[Fabricantes]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fabricantes](
	[FabricanteID] [int] NOT NULL,
	[NomeFabricante] [nvarchar](100) NOT NULL,
	[Endereco] [nvarchar](255) NOT NULL,
	[Telefone] [nvarchar](15) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[FabricanteID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[FormaPgto]

-- %%
/****** Object:  Table [dbo].[FormaPgto]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[FormaPgto](
	[FormaPgtoID] [int] NOT NULL,
	[NomeFormaPgto] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[FormaPgtoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Fornecedor]

-- %%
/****** Object:  Table [dbo].[Fornecedor]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Fornecedor](
	[FornecedorID] [int] NOT NULL,
	[NomeFornecedor] [nvarchar](100) NOT NULL,
	[Cnpj] [nvarchar](20) NULL,
	[Endereco] [nvarchar](255) NULL,
	[Telefone] [nvarchar](15) NULL,
	[Email] [nvarchar](100) NULL,
	[CidadeID] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[FornecedorID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ItemVenda]

-- %%
/****** Object:  Table [dbo].[ItemVenda]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ItemVenda](
	[VendaID] [uniqueidentifier] NULL,
	[ProdutoID] [int] NOT NULL,
	[Quantidade] [int] NOT NULL,
	[PrecoUnitario] [decimal](10, 2) NOT NULL,
	[Subtotal]  AS ([Quantidade]*[PrecoUnitario]),
	[ItemVendaID] [uniqueidentifier] NOT NULL,
 CONSTRAINT [PK_ItemVenda] PRIMARY KEY CLUSTERED 
(
	[ItemVendaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pagamento]

-- %%
/****** Object:  Table [dbo].[Pagamento]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pagamento](
	[PagamentoID] [int] NOT NULL,
	[ParcelaID] [int] NULL,
	[DataPagamento] [datetime] NULL,
	[ValorPago] [decimal](10, 2) NULL,
	[MetodoPagamento] [nvarchar](50) NULL,
	[Observacao] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[PagamentoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Parcela]

-- %%
/****** Object:  Table [dbo].[Parcela]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Parcela](
	[VendaID] [uniqueidentifier] NOT NULL,
	[NumeroParcela] [int] NOT NULL,
	[DataVencimento] [datetime] NOT NULL,
	[ValorParcela] [decimal](18, 2) NOT NULL,
	[ValorRecebido] [decimal](18, 2) NOT NULL,
	[SaldoRestante] [decimal](18, 2) NOT NULL,
	[Pago] [bit] NOT NULL,
	[ParcelaID] [uniqueidentifier] NOT NULL,
 CONSTRAINT [PK_Parcela] PRIMARY KEY CLUSTERED 
(
	[ParcelaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Produto]

-- %%
/****** Object:  Table [dbo].[Produto]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Produto](
	[ProdutoID] [int] NOT NULL,
	[NomeProduto] [nvarchar](100) NULL,
	[PrecoCusto] [decimal](18, 2) NULL,
	[Estoque] [int] NULL,
	[PrecoVenda] [decimal](18, 0) NULL,
PRIMARY KEY CLUSTERED 
(
	[ProdutoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Produtos]

-- %%
/****** Object:  Table [dbo].[Produtos]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Produtos](
	[ProdutoID] [int] IDENTITY(1,1) NOT NULL,
	[NomeProduto] [varchar](100) NOT NULL,
	[Descricao] [varchar](100) NOT NULL,
	[PrecoCusto] [decimal](10, 2) NOT NULL,
	[Lucro] [decimal](10, 2) NOT NULL,
	[PrecoDeVenda] [decimal](10, 2) NOT NULL,
	[QuantidadeEmEstoque] [int] NOT NULL,
	[DataDeEntrada] [datetime] NOT NULL,
	[CategoriaID] [int] NULL,
	[FabricanteID] [int] NULL,
	[UnidadeDeMedida] [varchar](50) NULL,
	[Status] [varchar](50) NULL,
	[DataDeVencimento] [datetime] NULL,
	[Imagem] [varbinary](max) NULL,
	[FornecedorID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ProdutoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Recebimentos]

-- %%
/****** Object:  Table [dbo].[Recebimentos]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Recebimentos](
	[RecebimentoID] [uniqueidentifier] NOT NULL,
	[VendaID] [uniqueidentifier] NOT NULL,
	[DataRecebimento] [date] NULL,
	[ValorRecebido] [decimal](18, 2) NULL,
	[ParcelaID] [uniqueidentifier] NULL,
	[ContaReceberID] [uniqueidentifier] NOT NULL,
	[DataRegistro] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[RecebimentoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SubCategoria]

-- %%
/****** Object:  Table [dbo].[SubCategoria]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SubCategoria](
	[SubCategoriaID] [int] NOT NULL,
	[NomeSubCategoria] [nvarchar](100) NOT NULL,
	[CategoriaID] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[SubCategoriaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuario]

-- %%
/****** Object:  Table [dbo].[Usuario]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuario](
	[UsuarioID] [int] NOT NULL,
	[NomeUsuario] [nvarchar](100) NOT NULL,
	[Email] [nvarchar](100) NOT NULL,
	[Senha] [nvarchar](100) NOT NULL,
	[TipoUsuario] [nvarchar](20) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[UsuarioID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Venda]

-- %%
/****** Object:  Table [dbo].[Venda]    Script Date: 19/01/2025 15:39:00 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Venda](
	[ClienteID] [int] NOT NULL,
	[DataVenda] [datetime] NOT NULL,
	[ValorTotal] [decimal](10, 2) NOT NULL,
	[VendaID] [uniqueidentifier] NOT NULL,
 CONSTRAINT [PK_Venda] PRIMARY KEY CLUSTERED 
(
	[VendaID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__ContaRece__Valor__681373AD]

-- %%
ALTER TABLE [dbo].[ContaReceber] ADD  DEFAULT ((0)) FOR [ValorRecebido]
GO

-- %% [markdown]
-- # [DF__ContaReceb__Pago__690797E6]

-- %%
ALTER TABLE [dbo].[ContaReceber] ADD  DEFAULT ((0)) FOR [Pago]
GO

-- %% [markdown]
-- # [DF__ContaRece__Conta__671F4F74]

-- %%
ALTER TABLE [dbo].[ContaReceber] ADD  DEFAULT (newid()) FOR [ContaReceberID]
GO

-- %% [markdown]
-- # [DF__ItemVenda__ItemV__7849DB76]

-- %%
ALTER TABLE [dbo].[ItemVenda] ADD  DEFAULT (newid()) FOR [ItemVendaID]
GO

-- %% [markdown]
-- # [DF__Parcela__ValorRe__6CD828CA]

-- %%
ALTER TABLE [dbo].[Parcela] ADD  DEFAULT ((0)) FOR [ValorRecebido]
GO

-- %% [markdown]
-- # [DF__Parcela__Pago__6DCC4D03]

-- %%
ALTER TABLE [dbo].[Parcela] ADD  DEFAULT ((0)) FOR [Pago]
GO

-- %% [markdown]
-- # [DF__Parcela__Parcela__6BE40491]

-- %%
ALTER TABLE [dbo].[Parcela] ADD  DEFAULT (newid()) FOR [ParcelaID]
GO

-- %% [markdown]
-- # [FK__Cidade__EstadoID__4CA06362]

-- %%
ALTER TABLE [dbo].[Cidade]  WITH CHECK ADD FOREIGN KEY([EstadoID])
REFERENCES [dbo].[Estado] ([EstadoID])
GO

-- %% [markdown]
-- # [FK_Cliente_Cidade]

-- %%
ALTER TABLE [dbo].[Cliente]  WITH CHECK ADD  CONSTRAINT [FK_Cliente_Cidade] FOREIGN KEY([CidadeID])
REFERENCES [dbo].[Cidade] ([CidadeID])
GO
ALTER TABLE [dbo].[Cliente] CHECK CONSTRAINT [FK_Cliente_Cidade]
GO

-- %% [markdown]
-- # [FK_ContaReceber_Parcela]

-- %%
ALTER TABLE [dbo].[ContaReceber]  WITH CHECK ADD  CONSTRAINT [FK_ContaReceber_Parcela] FOREIGN KEY([ParcelaID])
REFERENCES [dbo].[Parcela] ([ParcelaID])
GO
ALTER TABLE [dbo].[ContaReceber] CHECK CONSTRAINT [FK_ContaReceber_Parcela]
GO

-- %% [markdown]
-- # [FK_ContaReceber_Venda]

-- %%
ALTER TABLE [dbo].[ContaReceber]  WITH CHECK ADD  CONSTRAINT [FK_ContaReceber_Venda] FOREIGN KEY([VendaID])
REFERENCES [dbo].[Venda] ([VendaID])
GO
ALTER TABLE [dbo].[ContaReceber] CHECK CONSTRAINT [FK_ContaReceber_Venda]
GO

-- %% [markdown]
-- # [FK__ContasAPa__Forne__1BFD2C07]

-- %%
ALTER TABLE [dbo].[ContasAPagar]  WITH CHECK ADD FOREIGN KEY([FornecedorID])
REFERENCES [dbo].[Fornecedor] ([FornecedorID])
GO

-- %% [markdown]
-- # [FK_Fornecedor_Cidade]

-- %%
ALTER TABLE [dbo].[Fornecedor]  WITH CHECK ADD  CONSTRAINT [FK_Fornecedor_Cidade] FOREIGN KEY([CidadeID])
REFERENCES [dbo].[Cidade] ([CidadeID])
GO
ALTER TABLE [dbo].[Fornecedor] CHECK CONSTRAINT [FK_Fornecedor_Cidade]
GO

-- %% [markdown]
-- # [FK_ItemVenda_Produto]

-- %%
ALTER TABLE [dbo].[ItemVenda]  WITH CHECK ADD  CONSTRAINT [FK_ItemVenda_Produto] FOREIGN KEY([ProdutoID])
REFERENCES [dbo].[Produto] ([ProdutoID])
GO
ALTER TABLE [dbo].[ItemVenda] CHECK CONSTRAINT [FK_ItemVenda_Produto]
GO

-- %% [markdown]
-- # [FK_ItemVenda_Venda]

-- %%
ALTER TABLE [dbo].[ItemVenda]  WITH CHECK ADD  CONSTRAINT [FK_ItemVenda_Venda] FOREIGN KEY([VendaID])
REFERENCES [dbo].[Venda] ([VendaID])
GO
ALTER TABLE [dbo].[ItemVenda] CHECK CONSTRAINT [FK_ItemVenda_Venda]
GO

-- %% [markdown]
-- # [FK_Parcela_Venda]

-- %%
ALTER TABLE [dbo].[Parcela]  WITH CHECK ADD  CONSTRAINT [FK_Parcela_Venda] FOREIGN KEY([VendaID])
REFERENCES [dbo].[Venda] ([VendaID])
GO
ALTER TABLE [dbo].[Parcela] CHECK CONSTRAINT [FK_Parcela_Venda]
GO

-- %% [markdown]
-- # [FK__Produtos__Categoria]

-- %%
ALTER TABLE [dbo].[Produtos]  WITH CHECK ADD  CONSTRAINT [FK__Produtos__Categoria] FOREIGN KEY([CategoriaID])
REFERENCES [dbo].[Categoria] ([CategoriaID])
GO
ALTER TABLE [dbo].[Produtos] CHECK CONSTRAINT [FK__Produtos__Categoria]
GO

-- %% [markdown]
-- # [FK__Produtos__Fornececedor]

-- %%
ALTER TABLE [dbo].[Produtos]  WITH CHECK ADD  CONSTRAINT [FK__Produtos__Fornececedor] FOREIGN KEY([FornecedorID])
REFERENCES [dbo].[Fornecedor] ([FornecedorID])
GO
ALTER TABLE [dbo].[Produtos] CHECK CONSTRAINT [FK__Produtos__Fornececedor]
GO

-- %% [markdown]
-- # [FK_Produtos_Fabricante]

-- %%
ALTER TABLE [dbo].[Produtos]  WITH CHECK ADD  CONSTRAINT [FK_Produtos_Fabricante] FOREIGN KEY([FabricanteID])
REFERENCES [dbo].[Fabricantes] ([FabricanteID])
GO
ALTER TABLE [dbo].[Produtos] CHECK CONSTRAINT [FK_Produtos_Fabricante]
GO

-- %% [markdown]
-- # [FK_Recebimentos_ContaReceber]

-- %%
ALTER TABLE [dbo].[Recebimentos]  WITH CHECK ADD  CONSTRAINT [FK_Recebimentos_ContaReceber] FOREIGN KEY([ContaReceberID])
REFERENCES [dbo].[ContaReceber] ([ContaReceberID])
GO
ALTER TABLE [dbo].[Recebimentos] CHECK CONSTRAINT [FK_Recebimentos_ContaReceber]
GO

-- %% [markdown]
-- # [FK_Recebimentos_Parcela]

-- %%
ALTER TABLE [dbo].[Recebimentos]  WITH CHECK ADD  CONSTRAINT [FK_Recebimentos_Parcela] FOREIGN KEY([ParcelaID])
REFERENCES [dbo].[Parcela] ([ParcelaID])
GO
ALTER TABLE [dbo].[Recebimentos] CHECK CONSTRAINT [FK_Recebimentos_Parcela]
GO

-- %% [markdown]
-- # [FK_Recebimentos_Venda]

-- %%
ALTER TABLE [dbo].[Recebimentos]  WITH CHECK ADD  CONSTRAINT [FK_Recebimentos_Venda] FOREIGN KEY([VendaID])
REFERENCES [dbo].[Venda] ([VendaID])
GO
ALTER TABLE [dbo].[Recebimentos] CHECK CONSTRAINT [FK_Recebimentos_Venda]
GO

-- %% [markdown]
-- # [FK__SubCatego__Categ__24927208]

-- %%
ALTER TABLE [dbo].[SubCategoria]  WITH CHECK ADD FOREIGN KEY([CategoriaID])
REFERENCES [dbo].[Categoria] ([CategoriaID])
GO

-- %% [markdown]
-- # [bdsiscontrol]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [bdsiscontrol] SET  READ_WRITE 
GO
